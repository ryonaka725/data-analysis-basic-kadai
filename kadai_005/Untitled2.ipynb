# %%
import matplotlib.pyplot as plt

x = [0, 1, 2, 3]
y = [1, 2, -5, 2]
plt.plot(x, y)

# %%
import matplotlib.pyplot as plt
import numpy as np

# データを作成
# 0から10までの幅で配列を等間隔に100個作成する
x = np.linspace(0, 10, 100)
y= 2 + 2 * np.sin(2 * x)

# プロット
fig, ax = plt.subplots()

ax.plot(x, y, linewidth=2.0)

ax.plot(x, y, linewidth=2.0)

ax.set(xlim=(0, 10), xticks=np.arange(0, 10),
       ylim=(-1, 5), yticks=np.arange(-1, 6))

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# データを作成
# 0から10までの幅で配列を等間隔に30個作成する
x = np.linspace(0, 10, 30)
y= 2 + 2 * np.sin(2 * x)

# プロット
fig, ax = plt.subplots()

ax.plot(x, y, linewidth=2.0)

ax.set(xlim=(0, 10), xticks=np.arange(0, 10),
       ylim=(-1, 5), yticks=np.arange(-1, 6))

plt.show()

# %%
# 画像を読むためのライブラリをインポートする
import matplotlib.image as mpimg
# 画像を表示するためのライブラリをインポートする
import matplotlib.pyplot as plt

# 画像を読み込む
img = mpimg.imread('risu.jpg')
# 画像を表示する
plt.imshow(img)

# %%
# 画像を読むためのライブラリをインポートする
import matplotlib.image as mpimg
# 画像を表示するためのライブラリをインポートする
import matplotlib.pyplot as plt

# 画像を読み込む
img = mpimg.imread('risu.jpg')
# RGBのRの値を使って疑似カラーを付与
img = img[:, :, 0]
# 画像を表示する
plt.imshow(img)
# カラーバーの表示
plt.colorbar()

# %%
# 画像を読むためのライブラリをインポートする
import matplotlib.image as mpimg
# 画像を表示するためのライブラリをインポートする
import matplotlib.pyplot as plt

# 画像を読み込む
img = mpimg.imread('risu.jpg')
# 疑似カラーを付与（グレースケールにする）
img = img[:, :, 0]
# 画像を表示する
plt.imshow(img, cmap='gray')

# %%
import numpy as np
import matplotlib.pyplot as plt

# 平均が15、標準偏差5の標準正規分布から2000個の乱数を生成する
x = np.random.normal(15, 5, 2000)
# ヒストグラムをプロット
plt.hist(x)
# Out:
# (array([  2.,  22.,  99., 275., 504., 524., 380., 143.,  41.,  10.]),
#  array([-3.50790418,  0.05189937,  3.61170293,  7.17150649, 10.73131005,
#         14.29111361, 17.85091717, 21.41072073, 24.97052429, 28.53032785,
#         32.09013141]),
#  <BarContainer object of 10 artists>)

# %%
import numpy as np
import matplotlib.pyplot as plt

# 平均が15、標準偏差5の標準正規分布から2000個の乱数を生成する
x = np.random.normal(15, 5, 2000)
# ヒストグラムをプロット
plt.hist(x, bins=30)
# Out:
# (array([  2.,   2.,   1.,   3.,   7.,  11.,  27.,  23.,  49.,  69.,  92.,
#         129., 145., 204., 197., 183., 200., 158., 142., 115.,  91.,  62.,
#          45.,  24.,  12.,   1.,   2.,   2.,   1.,   1.]),
#  array([-3.8505378 , -2.61066034, -1.37078289, -0.13090544,  1.10897201,
#          2.34884947,  3.58872692,  4.82860437,  6.06848183,  7.30835928,
#          8.54823673,  9.78811418, 11.02799164, 12.26786909, 13.50774654,
#         14.74762399, 15.98750145, 17.2273789 , 18.46725635, 19.70713381,
#         20.94701126, 22.18688871, 23.42676616, 24.66664362, 25.90652107,
#         27.14639852, 28.38627598, 29.62615343, 30.86603088, 32.10590833,
#         33.34578579]),
#  <BarContainer object of 30 artists>)

# %%
import numpy as np
import matplotlib.pyplot as plt

# 平均が15、標準偏差5の標準正規分布から2000個の乱数を生成する
x = np.random.normal(15, 5, 2000)
plt.xlim(-10, 40)
# ヒストグラムをプロット
plt.hist(x, bins=30)
# Out:
# (array([  1.,   1.,   0.,   0.,   5.,   4.,  19.,  26.,  36.,  67.,  85.,
#         112., 138., 183., 196., 198., 193., 184., 154., 125.,  92.,  78.,
#          43.,  27.,  20.,   5.,   1.,   4.,   2.,   1.]),
#  array([-4.70776419, -3.46150837, -2.21525256, -0.96899674,  0.27725907,
#          1.52351489,  2.76977071,  4.01602652,  5.26228234,  6.50853815,
#          7.75479397,  9.00104979, 10.2473056 , 11.49356142, 12.73981723,
#         13.98607305, 15.23232887, 16.47858468, 17.7248405 , 18.97109632,
#         20.21735213, 21.46360795, 22.70986376, 23.95611958, 25.2023754 ,
#         26.44863121, 27.69488703, 28.94114284, 30.18739866, 31.43365448,
#         32.67991029]),
#  <BarContainer object of 30 artists>)

# %%
# !pip install japanize_matplotlib

import matplotlib.pyplot as plt
import japanize_matplotlib

# モーターから観測した音の周波数
hertz = [300, 200, 200, 500, 600, 2000, 1600, 1800, 1850, 1700, 1500, 1500, 1500, 1400, 5000, 6000, 2000, 300, 3000]
# 箱ひげ図
plt.boxplot(hertz)

# 日本語でタイトルを設定する
plt.title('モーター音の周波数 ')

#描画
plt.show()
# Out:
# Collecting japanize_matplotlib
#   Downloading japanize-matplotlib-1.1.3.tar.gz (4.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 18.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from japanize_matplotlib) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->japanize_matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->japanize_matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->japanize_matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->japanize_matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib->japanize_matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->japanize_matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->japanize_matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->japanize_matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->japanize_matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->japanize_matplotlib) (1.17.0)
# Building wheels for collected packages: japanize_matplotlib
#   Building wheel for japanize_matplotlib (setup.py) ... done
#   Created wheel for japanize_matplotlib: filename=japanize_matplotlib-1.1.3-py3-none-any.whl size=4120257 sha256=21cebd6f71d3190f00f94de5722ad71a89dac51c251a5c904c8f412379e50495
#   Stored in directory: /root/.cache/pip/wheels/c1/f7/9b/418f19a7b9340fc16e071e89efc379aca68d40238b258df53d
# Successfully built japanize_matplotlib
# Installing collected packages: japanize_matplotlib
# Successfully installed japanize_matplotlib-1.1.3

# %%
import matplotlib.pyplot as plt
import numpy as np

# データを生成する
np.random.seed(3)
x = 4 + np.random.normal(0, 2, 60)
y = 4 + np.random.normal(0, 2, len(x))

# プロットする
plt.scatter(x, y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import japanize_matplotlib

# 円グラフを描画
x = np.array([30, 40, 30])
label = ["いぬ", "ネコ", "その他"]
plt.title("好きな動物")
plt.pie(x, labels=label)
# Out:
# ([<matplotlib.patches.Wedge at 0x7933084781a0>,
#   <matplotlib.patches.Wedge at 0x793308526690>,
#   <matplotlib.patches.Wedge at 0x793308467e00>],
#  [Text(0.6465637011386807, 0.8899187493079641, 'いぬ'),
#   Text(-1.0999999999999959, -9.616505800409723e-08, 'ネコ'),
#   Text(0.6465640158668551, -0.8899185206445168, 'その他')])

# %%
import numpy as np
import matplotlib.pyplot as plt
import japanize_matplotlib

x = np.array([1, 2, 3, 4, 5])
y = np.array([100, 120, 150, 200, 160])
label = ["昆布", "うめ", "鮭", "カルビ", "すじこ"]
plt.title("おにぎりの具ごとの値段")
plt.bar(x, y, tick_label=label)
# Out:
# <BarContainer object of 5 artists>

# %%
import numpy as np
import matplotlib.pyplot as plt

# 描画領域全体にサブプロットを生成
fig, axes = plt.subplots(2, 3, tight_layout=True)

# 折れ線グラフ
x = [0, 1, 2, 3]
y0 = [1, 2, -5, 2]
axes[0,0].plot(y0)

# sin関数
# データを作成
# 0から10までの幅で配列を等間隔に100個作成する
x = np.linspace(0, 10, 100)
y = 2 + 2 * np.sin(2 * x)


axes[0,1].plot(x, y, linewidth=2.0)
axes[0,1].plot(x, y, linewidth=2.0)

axes[0,1].set(xlim=(0, 10), xticks=np.arange(0, 10),
       ylim=(-1, 5), yticks=np.arange(-1, 6))


#ヒストグラム
# 平均が15、標準偏差5の標準正規分布から2000個の乱数を生成する
x = np.random.normal(15, 5, 2000)
# ヒストグラムをプロット
axes[0,2].hist(x)


#散布図
# データを生成する
np.random.seed(3)
x = 4 + np.random.normal(0, 2, 60)
y = 4 + np.random.normal(0, 2, len(x))

# プロットする
axes[1,0].scatter(x, y)

plt.show()
